# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt') 
model.train(data=r"C:\Users\sunil\Downloads\archive (1)\Final Dataset(2)\data.yaml",
            epochs=10,
            imgsz=640,
            batch=16,
            name='yolov8_person_detection',
            device='cpu',
            verbose=True)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 49.7M/49.7M [00:44<00:00, 1.16MB/s]
# New https://pypi.org/project/ultralytics/8.2.87 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.83  Python-3.11.5 torch-2.2.0+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# ...

# %%
model.save(r'C:\Users\sunil\Downloads\cogniablenew10.pt')
